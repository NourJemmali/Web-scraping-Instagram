# %%
import re
import selenium
from unittest import result
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException,WebDriverException,StaleElementReferenceException
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support import expected_conditions
import random
import time
from selenium.webdriver.support import expected_conditions as EC
import json
import pandas as pd
from bs4 import BeautifulSoup as bs



CFG_USER_AGENTS = ['Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.96 Safari/537.36',
              'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.90 Safari/537.36',
              'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.72 Safari/537.36',
              'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.212 Safari/537.36',
              'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.93 Safari/537.36',
              'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.77 Safari/537.36',
              'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.114 Safari/537.36',
              'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.107 Safari/537.36',
              'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.131 Safari/537.36',
         
     'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/92.0.4515.159 Safari/537.36',
              'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/93.0.4577.82 Safari/537.36',
              'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/93.0.4577.63 Safari/537.36',
              'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.81 Safari/537.36',
              'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/94.0.4606.71 Safari/537.36'
              'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/95.0.4638.69 Safari/537.36',
              'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/95.0.4638.54 Safari/537.36',
              'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36'
              ]

chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument("--no-sandbox")
chrome_options.add_argument("--headless")
chrome_options.add_argument("--disable-gpu")
userAgent = random.choice(CFG_USER_AGENTS)
chrome_options.add_argument(f'user-agent={userAgent}')
chrome_driver =  webdriver.Chrome('/******/chromedriver_linux64/chromedriver',options=chrome_options)
chrome_driver.maximize_window()
#####################################################################**************############################################################
#page_url='https://www.instagram.com/******/'
page_url='https://www.instagram.com/******/'
###################################################################################### 
def _init_url():
        # go to init link https://www.instagram.com/
    chrome_driver.get('https://www.instagram.com/')
        

def _login(param_user_name, param_user_password):
        # try login to facebook
        try:
            # send user name & password
            WebDriverWait(chrome_driver, 10).until(EC.element_to_be_clickable((By.CSS_SELECTOR, "input[name='username']"))).send_keys(param_user_name)
            WebDriverWait(chrome_driver, 10).until(EC.element_to_be_clickable((By.CSS_SELECTOR, "input[name='password']"))).send_keys(param_user_password)
            # send click on log button
            WebDriverWait(chrome_driver, 2).until(EC.element_to_be_clickable((By.CSS_SELECTOR, "button[type='submit']"))).click()
            # wait few seconds for page change
            time.sleep(5)

        except:
            raise
def alerts():
    try:
        alert = WebDriverWait(chrome_driver , 15).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="react-root"]/section/main/div/div/div/div/button'))).click()
        time.sleep(5)
        alert2 = WebDriverWait(chrome_driver , 15).until(EC.element_to_be_clickable((By.XPATH, '/html/body/div[1]/div/div/div/div[2]/div/div/div[1]/div/div[2]/div/div/div/div/div/div/div/div[3]/button[2]'))).click()
    except:
        pass
def recherche(url_page):
    chrome_driver.get(url_page)
    time.sleep(10)
def reply():
    while True:
        try:
            reply= WebDriverWait(chrome_driver, 2).until(EC.element_to_be_clickable((By.XPATH, '//span[contains(text(), "View replies")]'))).click()
            time.sleep(2)
        except:
            break
#*******************************************************************************************************************************
if __name__ == '__main__':
    #print(selenium.__version__)
    _init_url()
    _login("*****", "*******")
    #_login("******", "******")
    alerts()
    recherche(page_url)
    #posts()

# %% [markdown]
# ## dict

# %%
dict={}
titre=likes_post=chrome_driver.find_elements(By.XPATH,'//div/div/div/div/div[1]/div/div/div/div[1]/div[1]/section/main/div/header/section/div[1]/h2')
dict["account_data"]={"account_name":titre[0].text,"account_url":page_url,"posts":[]}
dict

# %% [markdown]
# ### scrapping

# %%
def scraping_comment():
    while True:
        try:
            reply()
            click_plus= WebDriverWait(chrome_driver,5).until(EC.element_to_be_clickable((By.CSS_SELECTOR,'div > div > div > div > div:nth-child(4) > div > div > div.rq0escxv.l9j0dhe7.du4w35lb > div > div.iqfcb0g7.tojvnm2t.a6sixzi8.k5wvi7nf.q3lfd5jv.pk4s997a.bipmatt0.cebpdrjk.qowsmv63.owwhemhu.dp1hu0rb.dhp61c6y.l9j0dhe7.iyyx5f41.a8s20v7p > div > div > div > div > div.pi61vmqs.od1n8kyl.h6an9nv3.j4yusqav.djyw54ux.c9k30104.rxghi256.jhx0qe0y.mbxd2wpa.hb7lyos6.rfyvs5rk.sspdcydq.n34oi56o.c3wyshyw.im6prb7w.kzdz7bm1.k01ojvdi.alxbew3a.t78t6opn > div > article > div > div._aata > div > div > div._aasx > div._aat6 > ul > li > div > button > div > svg[aria-label="Load more comments"]'))).click()
            time.sleep(2)
        except:
            break
    res = chrome_driver.execute_script('return document.documentElement.outerHTML')
    soup = bs(res,'html.parser')
    try:
        comment_area=soup.find_all(lambda tag: tag.name == 'div' and tag.get('class') == ['_a9zo'])
        for div in comment_area:
        ### comments
            span = div.find('span',{'class': '_aacl _aaco _aacu _aacx _aad7 _aade'})
        #comment_text.append(span.text)
            comment_text=span.text
        ###likes comment
            likes_c= div.find_all('div', {'class': '_aacl _aacn _aacw _adda _aacy _aad6 _aade'})
            if likes_c[0].text.split()[0].isalpha():
        #likes_comment.append('0')
                likes_comment='0'
            else:
        #likes_comment.append((likes_c[0].text.split())[0])
                likes_comment=(likes_c[0].text.split())[0]
        ######### dates comment
            date_c=div.find( 'time', {'class': '_a9ze _a9zf'})
            date_c1=date_c.get('datetime')
            date_c2=date_c.get('title')
        ######### author name and url
            author= div.find('a',{'class': 'oajrlxb2 g5ia77u1 qu0x051f esr5mh6w e9989ue4 r7d6kgcz rq0escxv nhd2j8a9 nc684nl6 p7hjln8o kvgmc6g5 cxmmr5t8 oygrvhab hcukyx3x jb3vyjys rz4wbd8a qt6c0cv9 a8nywdso i1ao9s8h esuyzwwr f1sip0of lzcic4wl _acan _acao _acat _acaw _a6hd'})
            author_name=author.text
            author_url='https://www.instagram.com'+author.get('href')
    ################### dict
            if (author_name!=dict["account_data"]["account_name"]):
                dict["account_data"]["posts"][i]["comments"].append({"author_name":author_name,"author_url":author_url,"comment_text":comment_text,
                                                       "date_c1":date_c1,"date_c2":date_c2,"likes_comment":likes_comment })
    except:
        comment_area=[]
    return(len(comment_area))

# %%
#click_img= WebDriverWait(chrome_driver ,10).until(EC.element_to_be_clickable((By.XPATH, '//div[1]/div/div/div/div[1]/div/div/div/div[1]/div[1]/section/main/div/div[2]/article/div[1]/div/div[1]/div[1]'))).click()
click_img= WebDriverWait(chrome_driver ,10).until(EC.element_to_be_clickable((By.XPATH, '//div[@class="_aagw"]'))).click()
i=0
nbr_com=0
while True:
    time.sleep(3)
        ###################### posts######################
    res = chrome_driver.execute_script('return document.documentElement.outerHTML')
    soup = bs(res,'html.parser')
    try:
        post_area=soup.find( 'div', {'class': '_a9zr'})
    except:
        pass
    ##### lien
    try:
        link=soup.find( 'a', {'class': 'oajrlxb2 g5ia77u1 qu0x051f esr5mh6w e9989ue4 r7d6kgcz rq0escxv nhd2j8a9 nc684nl6 p7hjln8o kvgmc6g5 cxmmr5t8 oygrvhab hcukyx3x jb3vyjys rz4wbd8a qt6c0cv9 a8nywdso i1ao9s8h esuyzwwr f1sip0of lzcic4wl _aaqd _a6hd'})
        post_url='https://www.instagram.com'+link.get('href')
    except:
        pass
    ##### post text
    try:    
        post_text=post_area.find( 'span', {'class': '_aacl _aaco _aacu _aacx _aad7 _aade'}).text
    except:
        post_text=""   
    #### post author
    try:
        post_author=post_area.find( 'a', {'class': 'oajrlxb2 g5ia77u1 qu0x051f esr5mh6w e9989ue4 r7d6kgcz rq0escxv nhd2j8a9 nc684nl6 p7hjln8o kvgmc6g5 cxmmr5t8 oygrvhab hcukyx3x jb3vyjys rz4wbd8a qt6c0cv9 a8nywdso i1ao9s8h esuyzwwr f1sip0of lzcic4wl _acan _acao _acat _acaw _a6hd'}).text
    except:
        post_author=""

    ##### nbr of likes
    try:
        likes_post=chrome_driver.find_elements(By.XPATH, '//div/div/div/div/div[2]/div/div/div[1]/div/div[3]/div/div/div/div/div[2]/div/article/div/div[2]/div/div/div[2]/section[2]/div/div/div/a/div/span')
        likes=likes_post[0].text  
    except:
        click_view1= WebDriverWait(chrome_driver ,2).until(EC.element_to_be_clickable((By.XPATH, '//div/div/div/div/div[2]/div/div/div[1]/div/div[3]/div/div/div/div/div[2]/div/article/div/div[2]/div/div/div[2]/section[2]/div/span/div')))
        if click_view1 :
            click_view1.click()
            likes_post=chrome_driver.find_elements(By.XPATH, '//div/div/div/div/div[2]/div/div/div[1]/div/div[3]/div/div/div/div/div[2]/div/article/div/div[2]/div/div/div[2]/section[2]/div/div/div[4]/span')
            likes=likes_post[0].text
            click_view2= WebDriverWait(chrome_driver ,2).until(EC.element_to_be_clickable((By.XPATH, '//div/div/div/div/div[2]/div/div/div[1]/div/div[3]/div/div/div/div/div[2]/div/article/div/div[2]/div/div/div[2]'))).click()
        else:
            likes='0' 
    ##### post date
    try:
        date_p=soup.find( 'time', {'class': '_aaqe'})
        date_p1=date_p.get('datetime')
        date_p2=date_p.get('title')
    ###### dict#####
        dict["account_data"]["posts"].append({"post_url":post_url,"post_text":post_text,"post_author":post_author,"date_p1":date_p1,"date_p2":date_p2,"likes":likes,"nbr_com":"","comments":[]})
    except:
        pass
#####post nbr comments
    nbr_com=scraping_comment()
############## dict
    dict["account_data"]["posts"][i]["nbr_com"]=nbr_com
    i+=1
    try:
        click_next= WebDriverWait(chrome_driver,5).until(EC.element_to_be_clickable((By.CSS_SELECTOR,'div > div > div > div > div:nth-child(4) > div > div > div.rq0escxv.l9j0dhe7.du4w35lb > div > div.iqfcb0g7.tojvnm2t.a6sixzi8.k5wvi7nf.q3lfd5jv.pk4s997a.bipmatt0.cebpdrjk.qowsmv63.owwhemhu.dp1hu0rb.dhp61c6y.l9j0dhe7.iyyx5f41.a8s20v7p > div > div > div > div > div._a3gq > div > div > div > button > div > span > svg[aria-label="Next"]')))
        if click_next:
            print("true")
            click_next.click()
            print(post_url)
        else:
            print("false")
            print(post_url)
    except:
        print("break")
        break
print(i)

# %% [markdown]
# ## Convert to json

# %%
with open('data_insta.json', 'w', encoding='utf-8') as json_file:
                json.dump(dict, json_file,
                          ensure_ascii=False, indent=3)
